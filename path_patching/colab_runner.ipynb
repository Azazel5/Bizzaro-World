# %% [markdown]
# # Colab Runner
# Run the path patching experiments in Colab and download the saved results.

# %%
# !git clone https://github.com/YOUR_REPO/bizzaroworld

# %%
# !pip install transformer_lens plotly

# %%
# %cd bizzaroworld/path_patching

# %%
# !nvidia-smi

# %%
# !python run_experiments.py --model gemma_2b

# %%
# !python run_experiments.py --model gemma_12b

# %%
import shutil
shutil.make_archive("results", "zip", "results")
from google.colab import files
files.download("results.zip")
